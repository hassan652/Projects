# %% [markdown]
# IMPORTING LIBRARIES

# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure 

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (20,12)  #adjusts the configuration of the plots we will create

# %% [markdown]
# READING THE DATASET

# %%
df = pd.read_csv('movies.csv')

# %%
#Display the entire dataset

pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#        budget                                 company country        director  \
# 0   8000000.0           Columbia Pictures Corporation     USA      Rob Reiner
# 1   6000000.0                      Paramount Pictures     USA     John Hughes
# 2  15000000.0                      Paramount Pictures     USA      Tony Scott
# 3  18500000.0  Twentieth Century Fox Film Corporation     USA   James Cameron
# 4   9000000.0                    Walt Disney Pictures     USA  Randal Kleiser
#
#        genre        gross                      name rating    released  \
# 0  Adventure   52287414.0               Stand by Me      R  1986-08-22
# 1     Comedy   70136369.0  Ferris Bueller's Day Off  PG-13  1986-06-11
# 2     Action  179800601.0                   Top Gun     PG  1986-05-16
# 3     Action   85160248.0                    Aliens      R  1986-07-18
# 4  Adventure   18564613.0   Flight of the Navigator     PG  1986-08-01
#
#    runtime  score               star   votes         writer  year
# 0       89    8.1        Wil Wheaton  299174   Stephen King  1986
# 1      103    7.8  Matthew Broderick  264740    John Hughes  1986
# 2      110    6.9         Tom Cruise  236909       Jim Cash  1986
# 3      137    8.4   Sigourney Weaver  540152  James Cameron  1986
# 4       90    6.9        Joey Cramer   36636  Mark H. Baker  1986

# %% [markdown]
# CLEANING / EDA

# %%
#Checking for missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# budget - 0.0%
# company - 0.0%
# country - 0.0%
# director - 0.0%
# genre - 0.0%
# gross - 0.0%
# name - 0.0%
# rating - 0.0%
# released - 0.0%
# runtime - 0.0%
# score - 0.0%
# star - 0.0%
# votes - 0.0%
# writer - 0.0%
# year - 0.0%

# %%
#Checking data types for the columns

df.dtypes
# Out:
# budget      float64
# company      object
# country      object
# director     object
# genre        object
# gross       float64
# name         object
# rating       object
# released     object
# runtime       int64
# score       float64
# star         object
# votes         int64
# writer       object
# year          int64
# dtype: object

# %%
#Assigning proper data types

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
#As release data and release year are not similar in some cases, making a new column with correct entries

df['release year'] = df['released'].str[:4]

# %%
df.head()
df.shape
# Out:
# (6820, 16)

# %%
#Dropping duplicates

df['name'] = df['name'].drop_duplicates()

# %%
df.shape
# Out:
# (6820, 16)

# %%
#ordering by gross revenue

df = df.sort_values(by= ['gross'], inplace = False, ascending = False)

# %% [markdown]
# ANALYSIS AND VISUALIZATION

# %%
#checking correlation (only works on numerical fields)
#Correlation methods: pearson, kendall, spearman
df.corr(method = 'pearson')
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.712196  0.268226  0.042145  0.503924  0.291009
# gross    0.712196  1.000000  0.224579  0.165693  0.662457  0.191548
# runtime  0.268226  0.224579  1.000000  0.395343  0.317399  0.087639
# score    0.042145  0.165693  0.395343  1.000000  0.393607  0.105276
# votes    0.503924  0.662457  0.317399  0.393607  1.000000  0.229304
# year     0.291009  0.191548  0.087639  0.105276  0.229304  1.000000

# %%
#visualizing the correlation matrix with just numeric values

correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot= True)

plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
#Converting all columns to numerical values so that correlation can be measured using visualization

df_num = df

for col_name in df_num.columns:
    if df_num[col_name].dtype == 'object':
        df_num[col_name] = df_num[col_name].astype('category')
        df_num[col_name] = df_num[col_name].cat.codes

df.head()
# Out:
#          budget  company  country  director  genre      gross  name  rating  \
# 6380  245000000     1428       54      1037      0  936662225  4679       7
# 5061  237000000     2062       53      1066      0  760507625   501       7
# 2420  200000000     2062       54      1066      6  658672302  6177       7
# 6391  150000000     2085       54       466      0  652270625  2721       7
# 5723  220000000     1491       54      1412      0  623357910    -1       7
#
#       released  runtime  score  star    votes  writer  year  release year
# 6380      2290      136    8.1   475   687192    2356  2015            29
# 5061      1800      162    7.8  2084   954412    1629  2009            23
# 2420       910      194    7.8  1444   862554    1629  1997            11
# 6391      2247      124    7.0   404   469200    3310  2015            29
# 5723      1987      143    8.1  2001  1064633    2145  2012            26

# %%
#Visualizing correlation matrix with all features

correlation_matrix = df_num.corr()
sns.heatmap(correlation_matrix, annot= True)

plt.title('Correlation Matrix for All Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
correlation_matrix = df_num.corr()
corr_pairs = correlation_matrix.unstack()
corr_pairs
# Out:
# budget        budget          1.000000
#               company         0.187205
#               country         0.137635
#               director        0.011602
#               genre          -0.346794
#               gross           0.712196
#               name            0.021145
#               rating         -0.119660
#               released        0.276635
#               runtime         0.268226
#               score           0.042145
#               star           -0.015062
#               votes           0.503924
#               writer         -0.015611
#               year            0.291009
#               release year    0.274820
# company       budget          0.187205
#               company         1.000000
#               country         0.107950
#               director        0.004320
#               genre          -0.068330
#               gross           0.187220
#               name            0.017537
#               rating         -0.062250
#               released        0.027898
#               runtime         0.033058
#               score          -0.010426
#               star           -0.003160
#               votes           0.138662
#               writer         -0.004032
#               year            0.036272
#               release year    0.028012
# country       budget          0.137635
#               company         0.107950
#               country         1.000000
#               director        0.003699
#               genre          -0.042793
#               gross           0.149988
#               name            0.022533
#               rating          0.057979
#               released       -0.062609
#               runtime        -0.081796
#               score          -0.174414
#               star           -0.014569
#               votes           0.078657
#               writer          0.024982
#               year           -0.045204
#               release year   -0.062707
# director      budget          0.011602
#               company         0.004320
#               country         0.003699
#               director        1.000000
#               genre          -0.027669
#               gross          -0.011429
#               name            0.005401
#               rating          0.021926
#               released        0.001440
#               runtime         0.026779
#               score           0.017130
#               star            0.039813
#               votes           0.000639
#               writer          0.298997
#               year           -0.000087
#               release year    0.001823
# genre         budget         -0.346794
#               company        -0.068330
#               country        -0.042793
#               director       -0.027669
#               genre           1.000000
#               gross          -0.242676
#               name            0.021592
#               rating          0.100960
#               released       -0.039179
#               runtime        -0.041357
#               score           0.056234
#               star            0.008140
#               votes          -0.150519
#               writer         -0.000608
#               year           -0.046259
#               release year   -0.039014
# gross         budget          0.712196
#               company         0.187220
#               country         0.149988
#               director       -0.011429
#               genre          -0.242676
#               gross           1.000000
#               name            0.014610
#               rating         -0.135538
#               released        0.178564
#               runtime         0.224579
#               score           0.165693
#               star            0.008381
#               votes           0.662457
#               writer         -0.009455
#               year            0.191548
#               release year    0.176879
# name          budget          0.021145
#               company         0.017537
#               country         0.022533
#               director        0.005401
#               genre           0.021592
#               gross           0.014610
#               name            1.000000
#               rating          0.001317
#               released        0.006444
#               runtime         0.007405
#               score           0.021042
#               star           -0.004212
#               votes           0.015918
#               writer          0.011534
#               year            0.006943
#               release year    0.005732
# rating        budget         -0.119660
#               company        -0.062250
#               country         0.057979
#               director        0.021926
#               genre           0.100960
#               gross          -0.135538
#               name            0.001317
#               rating          1.000000
#               released        0.016696
#               runtime         0.079542
#               score           0.019271
#               star            0.007891
#               votes           0.011678
#               writer          0.010741
#               year            0.016221
#               release year    0.017438
# released      budget          0.276635
#               company         0.027898
#               country        -0.062609
#               director        0.001440
#               genre          -0.039179
#               gross           0.178564
#               name            0.006444
#               rating          0.016696
#               released        1.000000
#               runtime         0.091102
#               score           0.119577
#               star           -0.025506
#               votes           0.221736
#               writer         -0.004634
#               year            0.996187
#               release year    0.999389
# runtime       budget          0.268226
#               company         0.033058
#               country        -0.081796
#               director        0.026779
#               genre          -0.041357
#               gross           0.224579
#               name            0.007405
#               rating          0.079542
#               released        0.091102
#               runtime         1.000000
#               score           0.395343
#               star            0.016019
#               votes           0.317399
#               writer          0.000759
#               year            0.087639
#               release year    0.088342
# score         budget          0.042145
#               company        -0.010426
#               country        -0.174414
#               director        0.017130
#               genre           0.056234
#               gross           0.165693
#               name            0.021042
#               rating          0.019271
#               released        0.119577
#               runtime         0.395343
#               score           1.000000
#               star            0.009483
#               votes           0.393607
#               writer          0.012223
#               year            0.105276
#               release year    0.117679
# star          budget         -0.015062
#               company        -0.003160
#               country        -0.014569
#               director        0.039813
#               genre           0.008140
#               gross           0.008381
#               name           -0.004212
#               rating          0.007891
#               released       -0.025506
#               runtime         0.016019
#               score           0.009483
#               star            1.000000
#               votes          -0.011920
#               writer          0.035378
#               year           -0.026682
#               release year   -0.026052
# votes         budget          0.503924
#               company         0.138662
#               country         0.078657
#               director        0.000639
#               genre          -0.150519
#               gross           0.662457
#               name            0.015918
#               rating          0.011678
#               released        0.221736
#               runtime         0.317399
#               score           0.393607
#               star           -0.011920
#               votes           1.000000
#               writer          0.001154
#               year            0.229304
#               release year    0.220797
# writer        budget         -0.015611
#               company        -0.004032
#               country         0.024982
#               director        0.298997
#               genre          -0.000608
#               gross          -0.009455
#               name            0.011534
#               rating          0.010741
#               released       -0.004634
#               runtime         0.000759
#               score           0.012223
#               star            0.035378
#               votes           0.001154
#               writer          1.000000
#               year           -0.005664
#               release year   -0.004546
# year          budget          0.291009
#               company         0.036272
#               country        -0.045204
#               director       -0.000087
#               genre          -0.046259
#               gross           0.191548
#               name            0.006943
#               rating          0.016221
#               released        0.996187
#               runtime         0.087639
#               score           0.105276
#               star           -0.026682
#               votes           0.229304
#               writer         -0.005664
#               year            1.000000
#               release year    0.996229
# release year  budget          0.274820
#               company         0.028012
#               country        -0.062707
#               director        0.001823
#               genre          -0.039014
#               gross           0.176879
#               name            0.005732
#               rating          0.017438
#               released        0.999389
#               runtime         0.088342
#               score           0.117679
#               star           -0.026052
#               votes           0.220797
#               writer         -0.004546
#               year            0.996229
#               release year    1.000000
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre         budget         -0.346794
# budget        genre          -0.346794
# genre         gross          -0.242676
# gross         genre          -0.242676
# country       score          -0.174414
# score         country        -0.174414
# votes         genre          -0.150519
# genre         votes          -0.150519
# gross         rating         -0.135538
# rating        gross          -0.135538
#               budget         -0.119660
# budget        rating         -0.119660
# runtime       country        -0.081796
# country       runtime        -0.081796
# genre         company        -0.068330
# company       genre          -0.068330
# release year  country        -0.062707
# country       release year   -0.062707
#               released       -0.062609
# released      country        -0.062609
# company       rating         -0.062250
# rating        company        -0.062250
# year          genre          -0.046259
# genre         year           -0.046259
# country       year           -0.045204
# year          country        -0.045204
# genre         country        -0.042793
# country       genre          -0.042793
# runtime       genre          -0.041357
# genre         runtime        -0.041357
# released      genre          -0.039179
# genre         released       -0.039179
# release year  genre          -0.039014
# genre         release year   -0.039014
# director      genre          -0.027669
# genre         director       -0.027669
# star          year           -0.026682
# year          star           -0.026682
# star          release year   -0.026052
# release year  star           -0.026052
# released      star           -0.025506
# star          released       -0.025506
# budget        writer         -0.015611
# writer        budget         -0.015611
# star          budget         -0.015062
# budget        star           -0.015062
# star          country        -0.014569
# country       star           -0.014569
# star          votes          -0.011920
# votes         star           -0.011920
# director      gross          -0.011429
# gross         director       -0.011429
# score         company        -0.010426
# company       score          -0.010426
# writer        gross          -0.009455
# gross         writer         -0.009455
# writer        year           -0.005664
# year          writer         -0.005664
# released      writer         -0.004634
# writer        released       -0.004634
# release year  writer         -0.004546
# writer        release year   -0.004546
# star          name           -0.004212
# name          star           -0.004212
# writer        company        -0.004032
# company       writer         -0.004032
# star          company        -0.003160
# company       star           -0.003160
# writer        genre          -0.000608
# genre         writer         -0.000608
# director      year           -0.000087
# year          director       -0.000087
# director      votes           0.000639
# votes         director        0.000639
# runtime       writer          0.000759
# writer        runtime         0.000759
#               votes           0.001154
# votes         writer          0.001154
# rating        name            0.001317
# name          rating          0.001317
# released      director        0.001440
# director      released        0.001440
#               release year    0.001823
# release year  director        0.001823
# country       director        0.003699
# director      country         0.003699
#               company         0.004320
# company       director        0.004320
# director      name            0.005401
# name          director        0.005401
# release year  name            0.005732
# name          release year    0.005732
#               released        0.006444
# released      name            0.006444
# year          name            0.006943
# name          year            0.006943
#               runtime         0.007405
# runtime       name            0.007405
# star          rating          0.007891
# rating        star            0.007891
# star          genre           0.008140
# genre         star            0.008140
# star          gross           0.008381
# gross         star            0.008381
# star          score           0.009483
# score         star            0.009483
# rating        writer          0.010741
# writer        rating          0.010741
# name          writer          0.011534
# writer        name            0.011534
# budget        director        0.011602
# director      budget          0.011602
# votes         rating          0.011678
# rating        votes           0.011678
# score         writer          0.012223
# writer        score           0.012223
# name          gross           0.014610
# gross         name            0.014610
# name          votes           0.015918
# votes         name            0.015918
# runtime       star            0.016019
# star          runtime         0.016019
# year          rating          0.016221
# rating        year            0.016221
# released      rating          0.016696
# rating        released        0.016696
# score         director        0.017130
# director      score           0.017130
# rating        release year    0.017438
# release year  rating          0.017438
# name          company         0.017537
# company       name            0.017537
# rating        score           0.019271
# score         rating          0.019271
# name          score           0.021042
# score         name            0.021042
# budget        name            0.021145
# name          budget          0.021145
#               genre           0.021592
# genre         name            0.021592
# rating        director        0.021926
# director      rating          0.021926
# country       name            0.022533
# name          country         0.022533
# country       writer          0.024982
# writer        country         0.024982
# director      runtime         0.026779
# runtime       director        0.026779
# released      company         0.027898
# company       released        0.027898
# release year  company         0.028012
# company       release year    0.028012
#               runtime         0.033058
# runtime       company         0.033058
# writer        star            0.035378
# star          writer          0.035378
# company       year            0.036272
# year          company         0.036272
# director      star            0.039813
# star          director        0.039813
# score         budget          0.042145
# budget        score           0.042145
# genre         score           0.056234
# score         genre           0.056234
# country       rating          0.057979
# rating        country         0.057979
# country       votes           0.078657
# votes         country         0.078657
# rating        runtime         0.079542
# runtime       rating          0.079542
#               year            0.087639
# year          runtime         0.087639
# runtime       release year    0.088342
# release year  runtime         0.088342
# released      runtime         0.091102
# runtime       released        0.091102
# rating        genre           0.100960
# genre         rating          0.100960
# year          score           0.105276
# score         year            0.105276
# country       company         0.107950
# company       country         0.107950
# score         release year    0.117679
# release year  score           0.117679
# score         released        0.119577
# released      score           0.119577
# budget        country         0.137635
# country       budget          0.137635
# votes         company         0.138662
# company       votes           0.138662
# country       gross           0.149988
# gross         country         0.149988
# score         gross           0.165693
# gross         score           0.165693
#               release year    0.176879
# release year  gross           0.176879
# released      gross           0.178564
# gross         released        0.178564
# company       budget          0.187205
# budget        company         0.187205
# company       gross           0.187220
# gross         company         0.187220
# year          gross           0.191548
# gross         year            0.191548
# release year  votes           0.220797
# votes         release year    0.220797
# released      votes           0.221736
# votes         released        0.221736
# runtime       gross           0.224579
# gross         runtime         0.224579
# votes         year            0.229304
# year          votes           0.229304
# budget        runtime         0.268226
# runtime       budget          0.268226
# budget        release year    0.274820
# release year  budget          0.274820
# budget        released        0.276635
# released      budget          0.276635
# budget        year            0.291009
# year          budget          0.291009
# director      writer          0.298997
# writer        director        0.298997
# votes         runtime         0.317399
# runtime       votes           0.317399
# votes         score           0.393607
# score         votes           0.393607
# runtime       score           0.395343
# score         runtime         0.395343
# votes         budget          0.503924
# budget        votes           0.503924
# gross         votes           0.662457
# votes         gross           0.662457
# budget        gross           0.712196
# gross         budget          0.712196
# year          released        0.996187
# released      year            0.996187
# release year  year            0.996229
# year          release year    0.996229
# release year  released        0.999389
# released      release year    0.999389
# budget        budget          1.000000
# writer        writer          1.000000
# votes         votes           1.000000
# star          star            1.000000
# score         score           1.000000
# runtime       runtime         1.000000
# released      released        1.000000
# rating        rating          1.000000
# name          name            1.000000
# gross         gross           1.000000
# genre         genre           1.000000
# director      director        1.000000
# country       country         1.000000
# company       company         1.000000
# year          year            1.000000
# release year  release year    1.000000
# dtype: float64

# %%
highly_correlated = sorted_pairs[(sorted_pairs) > 0.5]
highly_correlated
# Out:
# votes         budget          0.503924
# budget        votes           0.503924
# gross         votes           0.662457
# votes         gross           0.662457
# budget        gross           0.712196
# gross         budget          0.712196
# year          released        0.996187
# released      year            0.996187
# release year  year            0.996229
# year          release year    0.996229
# release year  released        0.999389
# released      release year    0.999389
# budget        budget          1.000000
# writer        writer          1.000000
# votes         votes           1.000000
# star          star            1.000000
# score         score           1.000000
# runtime       runtime         1.000000
# released      released        1.000000
# rating        rating          1.000000
# name          name            1.000000
# gross         gross           1.000000
# genre         genre           1.000000
# director      director        1.000000
# country       country         1.000000
# company       company         1.000000
# year          year            1.000000
# release year  release year    1.000000
# dtype: float64

# %% [markdown]
# VOTES AND BUDGET HAVE THE HIGHEST CORRELATION

# %% [markdown]
# VISUALIZING

# %%
#Plotting a scatter plot

plt.scatter(x= df['budget'], y=df['gross'])
plt.title('Budget Vs Gross Earnings')
plt.xlabel('Gross Earnings (Millions)')
plt.ylabel('Budget for Film (100 Millions)')
plt.show()

# %%
#Plot the budget vs gross using seaborn

sns.regplot(x= 'budget', y= 'gross', data=df)
plt.title('Budget Vs Gross Earnings')
plt.xlabel('Gross Earnings (Millions)')
plt.ylabel('Budget for Film (100 Millions)')
plt.show()

# %%
#Changing colors for better visualization

sns.regplot(x= 'budget', y= 'gross', data=df, scatter_kws={'color': 'green'}, line_kws={'color':'blue'})
plt.title('Budget Vs Gross Earnings')
plt.xlabel('Gross Earnings (Millions)')
plt.ylabel('Budget for Film (100 Millions)')
plt.show()

# %%
sns.regplot(x= 'votes', y= 'gross', data=df, scatter_kws={'color': 'black'}, line_kws={'color':'red'})
plt.title('Votes Vs Gross Earnings')
plt.xlabel('Gross Earnings (Millions)')
plt.ylabel('Budget for Film (100 Millions)')
plt.show()

# %%
idx = df['gross']  # make an array of x-values

# call regplot on each axes
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=False)
sns.regplot(x=idx, y=df['budget'], ax=ax1, scatter_kws={'color': 'green'}, line_kws={'color':'blue'})
sns.regplot(x=idx, y=df['votes'], ax=ax2, scatter_kws={'color': 'black'}, line_kws={'color':'red'})
fig.set_size_inches(25, 10)

# %%
#Votes and budget have highest correlations to gross earnings
